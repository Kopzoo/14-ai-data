# %%
# 변수는 어떻게 만들까?
# 변수이름 = 변수에 저장한 값

# 변수명 규칙
# 1. 영문자, 숫자 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로는 시작할 수 없다.
# 3. 예약어(명령어)는 사용할 수 없다. (ex: print, add, sum ..)
# 4. 대소문자 구분 한다.

name = "홍길동"
name2 = "강호동"

# user-name = "홍길동"
user_name = "홍길동"
userName = 123

# 컨벤션
# user_name (O) 스네이크 스타일
# userName (O) 카멜 스타일
# UserName (O) 파스칼 스타일

# %%
a = [1, 2, 3]
print(id(a))
b = [1, 2, 3]
print(id(b))

a.append(4)
print(a)
print(id(a))
# Out:
# 1847330116992
# 1847334435904
# [1, 2, 3, 4]
# 1847330116992

# %%
b = a
print(id(b))
# Out:
# 1847330116992

# %%
a = [1, 2, 3]
b = a[:]
print(id(a))
print(id(b))
# Out:
# 1847334759680
# 1847334692992

# %%
# 변수를 만드는 여러가지 방법
a, b = ["python", "like"]
print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# python
# like
# <class 'str'>
# <class 'str'>

# %%
(a, b) = "python", "like"
print(a)
print(b)
print(type(a))
# Out:
# python
# like
# <class 'str'>

# %%
a = b = "python"
print(a)
print(b)
print(type(a))
# Out:
# python
# python
# <class 'str'>

# %%
a = 3
b = 5
a, b = b, a

print(a)
print(b)
# Out:
# 5
# 3
