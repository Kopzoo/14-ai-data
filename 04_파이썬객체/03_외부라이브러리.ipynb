# %%
from faker import Faker

fake = Faker()
fake.name()
# Out:
# 'Jake Jones'

# %%
fake.address()
# Out:
# '2387 Ryan Trafficway Apt. 143\nJenniferside, DC 40183'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(10)]
print(test_data)
# Out:
# [('Isabella Maldonado', 'PSC 0593, Box 0304\nAPO AP 06606'), ('Alan Bennett', '31289 Lori Mall\nTaylorchester, AZ 13028'), ('Antonio Avila', '70050 Joseph Roads\nSouth Erichaven, NJ 42915'), ('Ruben Castro', '3874 Robinson Gateway Suite 240\nNancyport, PR 03546'), ('Diana Whitaker', '0826 Johnson Garden Apt. 045\nTravisport, AL 83296'), ('Ashley Kennedy', '35841 Fischer Squares\nSmithborough, WA 59247'), ('Lisa Robinson', '6754 John Gardens Suite 889\nRiggsberg, AL 46668'), ('Glenda Dunn', '7665 Brown Green Apt. 090\nKellystad, DE 86302'), ('Paul Martin', '27974 Cathy Oval Suite 961\nRyanbury, MA 24151'), ('Brittany Taylor', 'USS Alvarez\nFPO AE 70182')]
